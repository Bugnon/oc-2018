# %% [markdown]
# # Matplotlib

# %%
import matplotlib
matplotlib.use('nbagg')
from matplotlib import pyplot as plt
import numpy as np
# Out:
# /Users/ho/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/Users/ho/anaconda3/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/ho/anaconda3/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/ho/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/ho/anaconda3/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/ho/anaconda3/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 497, in start
#     self.io_loop.start()
#   File "/Users/ho/anaconda3/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/ho/anaconda3/lib/python3.7/asyncio/base_events.py", line 523, in run_forever
#     self._run_once()
#   File "/Users/ho/anaconda3/lib/python3.7/asyncio/base_events.py", line 1758, in _run_once
#     handle._run()
#   File "/Users/ho/anaconda3/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/ho/anaconda3/lib/python3.7/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#   File "/Users/ho/anaconda3/lib/python3.7/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/ho/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 263, in enter_eventloop
#     self.eventloop(self)
#   File "/Users/ho/anaconda3/lib/python3.7/site-packages/ipykernel/eventloops.py", line 303, in loop_cocoa
#     kernel.do_one_iteration()
#   File "/Users/ho/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 298, in do_one_iteration
#     stream.flush(zmq.POLLIN, 1)
#   File "/Users/ho/anaconda3/lib/python3.7/site-packages/zmq/eventloop/zmqstream.py", line 357, in flush
#     self._handle_recv()
#   File "/Users/ho/anaconda3/lib/python3.7/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/Users/ho/anaconda3/lib/python3.7/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/Users/ho/anaconda3/lib/python3.7/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/ho/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/Users/ho/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/Users/ho/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/Users/ho/anaconda3/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/ho/anaconda3/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/ho/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/ho/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/ho/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2907, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/Users/ho/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2961, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-16-0f4edee6a3c8>", line 5, in <module>
#     get_ipython().run_line_magic('matplotlib', 'inline')
#   File "/Users/ho/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2131, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-107>", line 2, in matplotlib
#   File "/Users/ho/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/Users/ho/anaconda3/lib/python3.7/site-packages/IPython/core/magics/pylab.py", line 99, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/Users/ho/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3049, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/Users/ho/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py", line 311, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/Users/ho/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py", line 231, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/Users/ho/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py", line 1422, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/Users/ho/anaconda3/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "/Users/ho/anaconda3/lib/python3.7/site-packages/matplotlib/backends/__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()

# %%
# %matplotlib inline

# %% [markdown]
# These are the available **matplotlib** backends.

# %%
# %matplotlib --list
# Out:
# Available matplotlib backends: ['tk', 'gtk', 'gtk3', 'wx', 'qt4', 'qt5', 'qt', 'osx', 'nbagg', 'notebook', 'agg', 'svg', 'pdf', 'ps', 'inline', 'ipympl', 'widget']

# %% [markdown]
# This is the current one.

# %%
# %matplotlib
# Out:
# Using matplotlib backend: MacOSX

# %% [markdown]
# Import the necessary modules

# %%
plt.ioff()

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
# %matplotlib
# Out:
# Using matplotlib backend: MacOSX

# %% [markdown]
# ## Simple plot

# %% [markdown]
# Print a simple line plot

# %%
# Data for plotting
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2 * np.pi * t)

# Note that using plt.subplots below is equivalent to using
# fig = plt.figure() and then ax = fig.add_subplot(111)
fig, ax = plt.subplots()
ax.plot(t, s)

ax.set(xlabel='time (s)', ylabel='voltage (mV)',
       title='About as simple as it gets, folks')
ax.grid()

fig.savefig("test.png")
plt.show()

# %%
from ipywidgets import widgets

# %%
widgets.IntSlider()
# Out:
# IntSlider(value=0)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, xlim=(-1, 2), ylim=(-1, 2))
polygon = plt.Polygon([[0, 0], [1, 0], [1, 1], [0, 1], [0, 0]])
ax.add_patch(polygon)

# Function to be called when mouse is clicked
def on_click(event):
    if polygon.contains_point((event.x, event.y)):
        polygon.set_facecolor(np.random.random(3))
        fig.canvas.draw()

# Connect the click function to the button press event
fig.canvas.mpl_connect('button_press_event', on_click)
plt.show()

# %%
# %matplotlib
# Out:
# Using matplotlib backend: MacOSX

# %%
plt.ioffr()

# %%
plt.plot([1, 2, 3, 2, 1])
plt.show()

# %%
# %load /Users/raphael/GitHub/pygame/01_drawing.py

# %%
np.random.randint(10)
# Out:
# 8

# %% [markdown]
# ## plot

# %%
np.random.seed(1)
n = 5
x = np.arange(n)
y = np.random.randn(n)

fig, axes = plt.subplots(ncols=2, figsize=(6,3))
axes[0].plot(x)
axes[1].plot(x, y)
plt.show()

# %% [markdown]
# ## Scatter plot

# %%
np.random.seed(1)
n = 5
x = np.arange(n)
y = np.random.randn(n)
s = np.random.randn(n)*100

fig, axes = plt.subplots(ncols=2, figsize=(6,3))
axes[0].scatter(x, y)
axes[1].scatter(x, y, s)
plt.show()
# Out:
# /Users/raphael/anaconda3/lib/python3.6/site-packages/matplotlib/collections.py:902: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <img src="data:image/png;base64,..." width="600">
